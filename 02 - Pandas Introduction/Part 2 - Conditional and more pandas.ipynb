# %%
import numpy as np
import pandas as pd
from luwiji.pandas import illustration

# %%
df = pd.read_csv("data/cereal_imp.csv")
df.head()
# Out:
#    name                     name.1 mfr type  calories  protein  fat  sodium  \
# 0     0                  100% Bran   N    C        70        4    1     130
# 1     1          100% Natural Bran   Q    C       120        3    5      15
# 2     2                   All-Bran   K    C        70        4    1     260
# 3     3  All-Bran with Extra Fiber   K    C        50        4    0     140
# 4     4             Almond Delight   R    C       110        2    2     200
#
#    fiber  carbo  sugars      potass vitamins  shelf  weight  cups     rating
# 0   10.0    5.0     6.0  280.000000   FDA_25      3     1.0  0.33  68.402973
# 1    2.0    8.0     8.0  135.000000    FDA_0      3     1.0  1.00  33.983679
# 2    9.0    7.0     5.0  320.000000   FDA_25      3     1.0  0.33  59.425505
# 3   14.0    8.0     0.0  330.000000   FDA_25      3     1.0  0.50  93.704912
# 4    1.0   14.0     8.0   98.666667   FDA_25      3     1.0  0.75  34.384843

# %%
my_preferences = df.rename(columns={"name.1": "produk"})
my_preferences.head()
# Out:
#    name                     produk mfr type  calories  protein  fat  sodium  \
# 0     0                  100% Bran   N    C        70        4    1     130
# 1     1          100% Natural Bran   Q    C       120        3    5      15
# 2     2                   All-Bran   K    C        70        4    1     260
# 3     3  All-Bran with Extra Fiber   K    C        50        4    0     140
# 4     4             Almond Delight   R    C       110        2    2     200
#
#    fiber  carbo  sugars      potass vitamins  shelf  weight  cups     rating
# 0   10.0    5.0     6.0  280.000000   FDA_25      3     1.0  0.33  68.402973
# 1    2.0    8.0     8.0  135.000000    FDA_0      3     1.0  1.00  33.983679
# 2    9.0    7.0     5.0  320.000000   FDA_25      3     1.0  0.33  59.425505
# 3   14.0    8.0     0.0  330.000000   FDA_25      3     1.0  0.50  93.704912
# 4    1.0   14.0     8.0   98.666667   FDA_25      3     1.0  0.75  34.384843

# %%
my_preferences = df [(df.rating > 70) & (df.sugars < 5)]
my_preferences
# Out:
#     name                     name.1 mfr type  calories  protein  fat  sodium  \
# 3      3  All-Bran with Extra Fiber   K    C        50        4    0     140
# 64    64     Shredded Wheat 'n'Bran   N    C        90        3    0       0
# 65    65  Shredded Wheat spoon size   N    C        90        3    0       0
#
#     fiber  carbo  sugars  potass vitamins  shelf  weight  cups     rating
# 3    14.0    8.0     0.0   330.0   FDA_25      3     1.0  0.50  93.704912
# 64    4.0   19.0     0.0   140.0    FDA_0      1     1.0  0.67  74.472949
# 65    3.0   20.0     0.0   120.0    FDA_0      1     1.0  0.67  72.801787

# %%
my_preferences.sort_values("rating", ascending=False, ascending=False)
# Out:
#   Input In [11]
#     my_preferences.sort_values("rating", ascending=False, ascending=False)
#                                                           ^
# SyntaxError: keyword argument repeated: ascending

# %%
my_preferences = df[(df.rating < 60) & (df.mfr.isin(['K','N']))].copy
my_preferences()
# Out:
#     name                       name.1 mfr type  calories  protein  fat  \
# 2      2                     All-Bran   K    C        70        4    1
# 6      6                  Apple Jacks   K    C       110        2    0
# 16    16                  Corn Flakes   K    C       100        2    0
# 17    17                    Corn Pops   K    C       110        1    0
# 19    19           Cracklin' Oat Bran   K    C       110        3    3
# 21    21                      Crispix   K    C       110        2    0
# 24    24                  Froot Loops   K    C       110        2    1
# 25    25               Frosted Flakes   K    C       110        1    0
# 26    26          Frosted Mini-Wheats   K    C       100        3    0
# 28    28                Fruitful Bran   K    C       120        3    0
# 38    38  Just Right Crunchy  Nuggets   K    C       110        2    1
# 39    39       Just Right Fruit & Nut   K    C       140        3    1
# ...

# %%
my_preferences.sort.values("rating", ascending=False, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [13], in <cell line: 1>()
# ----> 1 my_preferences.sort.values("rating", ascending=False, inplace=True)
#
# AttributeError: 'function' object has no attribute 'sort'

# %% [markdown]
# # Groupby

# %%
df.groupby("shelf").mean()
# Out:
#             name    calories   protein   fat      sodium     fiber      carbo  \
# shelf
# 1      44.700000  102.500000  2.650000  0.60  176.250000  1.685000  16.590132
# 2      34.333333  109.523810  1.904762  1.00  145.714286  0.904762  13.619048
# 3      36.416667  107.777778  2.861111  1.25  158.611111  3.138889  14.500000
#
#          sugars      potass    weight      cups     rating
# shelf
# 1      5.201316   75.500000  0.991500  0.897000  46.145439
# 2      9.619048   62.555556  1.015714  0.911429  34.972827
# 3      6.527778  132.601852  1.058889  0.726111  45.220032

# %%
df.groupby(["mfr", "shelf"]).size()
# Out:
# mfr  shelf
# A    2         1
# G    1         6
#      2         7
#      3         9
# K    1         4
#      2         7
#      3        12
# N    1         3
#      2         2
#      3         1
# P    1         2
#      2         1
#      3         6
# Q    1         1
#      2         3
#      3         4
# R    1         4
#      3         4
# dtype: int64
